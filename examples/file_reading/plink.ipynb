# %% [markdown]
# # **Reading pLink Result Files**

# %%
from pyXLMS import __version__

print(f"Installed pyXLMS version: {__version__}")
# Out:
# Installed pyXLMS version: 1.4.3

# %%
from pyXLMS import parser
from pyXLMS import transform

# %% [markdown]
# All functionality to parse crosslink-spectrum-matches (CSMs) and crosslinks (XLs) from pLink result files is available via the `parser` submodule. We also import the `transform` submodule to show some summary statistics of the read files.

# %% [markdown]
# ## **Reading pLink Result Files via `parser.read()`**

# %%
parser_result = parser.read(
    "../../data/plink2/Cas9_plus10_2024.06.20.filtered_cross-linked_peptides.csv",
    engine="pLink",
    crosslinker="DSS",
)
# Out:
# Reading pLink crosslinks...: 100%|██████████| 252/252 [00:00<00:00, 19449.16it/s]

# %% [markdown]
# We can read any pLink result file using the `parser.read()` method and setting `engine="pLink"`. The method also requires us to specify the used crosslinker, in this case DSS was used (`crosslinker="DSS"`). You can read the documentation for the `parser.read()` method here: [**docs**](https://hgb-bin-proteomics.github.io/pyXLMS/pyXLMS.parser.html#pyXLMS.parser.read).

# %%
for k, v in parser_result.items():
    print(f"{k}: {type(v) if isinstance(v, list) else v}")
# Out:
# data_type: parser_result
# completeness: partial
# search_engine: pLink
# crosslink-spectrum-matches: None
# crosslinks: <class 'list'>

# %% [markdown]
# The `parser.read()` method returns a dictionary with a set of specified keys and their values. We refer to this dictionary as a `parser_result` object. All `parser.read*` methods return such a `parser_result` object, you can read more about that here: [**docs**](https://hgb-bin-proteomics.github.io/pyXLMS/pyXLMS.html#pyXLMS.data.create_parser_result), and here: [**data types specification**](https://github.com/hgb-bin-proteomics/pyXLMS/blob/master/docs/data_types.md).
#
# As you can see from the `parser_result` the pLink result file contained CSMs. We would be able to access those via `parser_result["crosslink-spectrum-matches"]`.

# %%
_ = transform.summary(parser_result)
# Out:
# Number of crosslinks: 252.0
# Number of unique crosslinks by peptide: 252.0
# Number of unique crosslinks by protein: 251.0
# Number of intra crosslinks: 249.0
# Number of inter crosslinks: 3.0
# Number of target-target crosslinks: 252.0
# Number of target-decoy crosslinks: 0.0
# Number of decoy-decoy crosslinks: 0.0
# Minimum crosslink score: nan
# Maximum crosslink score: nan

# %% [markdown]
# With the `transform.summary()` method we can also print out some summary statistics about our read CSMs. You can read more about the method here: [**docs**](https://hgb-bin-proteomics.github.io/pyXLMS/pyXLMS.transform.html#pyXLMS.transform.summary.summary).

# %%
sample_csm = parser_result["crosslink-spectrum-matches"][0]
for k, v in sample_csm.items():
    print(f"{k}: {v}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sample_csm = parser_result["crosslink-spectrum-matches"][0]
#       2 for k, v in sample_csm.items():
#       3     print(f"{k}: {v}")
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# Using `parser_result["crosslink-spectrum-matches"][0]` we can get the first CSM of the file and take a closer look at that.
#
# Here is an example CSM, you can learn more about the specific attributes and their values here: [**docs**](https://hgb-bin-proteomics.github.io/pyXLMS/pyXLMS.html#pyXLMS.data.create_csm), and here: [**data types specification**](https://github.com/hgb-bin-proteomics/pyXLMS/blob/master/docs/data_types.md).
#
# *****

# %%
parser_result = parser.read(
    "../../data/plink2/Cas9_plus10_2024.06.20.filtered_cross-linked_peptides.csv",
    engine="pLink",
    crosslinker="DSS",
)
# Out:
# Reading pLink crosslinks...: 100%|██████████| 252/252 [00:00<00:00, 14977.96it/s]

# %% [markdown]
# We can also as easily read a crosslink result file, notice how this time we also read a csv file instead of a txt file and don't even have to change anything. This is because when a filename is given, the parser will automatically detect the corresponding extension and use the correct sub-method.

# %%
_ = transform.summary(parser_result)
# Out:
# Number of crosslinks: 252.0
# Number of unique crosslinks by peptide: 252.0
# Number of unique crosslinks by protein: 251.0
# Number of intra crosslinks: 249.0
# Number of inter crosslinks: 3.0
# Number of target-target crosslinks: 252.0
# Number of target-decoy crosslinks: 0.0
# Number of decoy-decoy crosslinks: 0.0
# Minimum crosslink score: nan
# Maximum crosslink score: nan

# %% [markdown]
# Similarly, with the `transform.summary()` method we can also print out some summary statistics about our read crosslinks.

# %%
sample_crosslink = parser_result["crosslinks"][0]
for k, v in sample_crosslink.items():
    print(f"{k}: {v}")
# Out:
# data_type: crosslink
# completeness: partial
# alpha_peptide: AGFIKR
# alpha_peptide_crosslink_position: 5
# alpha_proteins: ['Cas9']
# alpha_proteins_crosslink_positions: [922]
# alpha_decoy: False
# beta_peptide: AGFIKR
# beta_peptide_crosslink_position: 5
# beta_proteins: ['Cas9']
# beta_proteins_crosslink_positions: [922]
# beta_decoy: False
# crosslink_type: intra
# score: None
# additional_information: None

# %% [markdown]
# Just like for the CSMs, we can also look into specific crosslinks using `parser_result["crosslinks"]`
#
# Here is an example crosslink, you can learn more about the specific attributes and their values here: [**docs**](https://hgb-bin-proteomics.github.io/pyXLMS/pyXLMS.html#pyXLMS.data.create_crosslink), and here: [**data types specification**](https://github.com/hgb-bin-proteomics/pyXLMS/blob/master/docs/data_types.md).
#
# *****

# %%
parser_result = parser.read(
    [
        "../../data/plink2/Cas9_plus10_2024.06.20.filtered_cross-linked_peptides.csv",
        "../../data/plink2/Cas9_plus10_2024.06.20.filtered_cross-linked_sites.csv",
    ],
    engine="pLink",
    crosslinker="DSS",
)
# Out:
# Reading pLink CSMs...: 100%|██████████| 961/961 [00:00<00:00, 17417.66it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 parser_result = parser.read(
#       2     [
#       3         "../../data/plink2/Cas9_plus10_2024.06.20.filtered_cross-linked_spectra.csv",
#       4         "../../data/plink2/Cas9_plus10_2024.06.20.filtered_cross-linked_sites.csv",
#       5     ],
#       6     engine="pLink",
#       7     crosslinker="DSS",
#       8 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyXLMS/parser/__init__.py:182, in read(files, engine, crosslinker, parse_modifications, ignore_errors, verbose, **kwargs)
#     180     return read_mzid(files, verbose=verbose, **kwargs)
#     181 if ff in ["plink", "plink2", "plink3", "plink 2", "plink 3"]:
# --> 182     return read_plink(
#     183         files, parse_modifications=parse_modifications, verbose=verbose, **kwargs
#     184     )
#     185 if ff in ["scout"]:
#     186     return read_scout(
#     187         files,
#     188         crosslinker=crosslinker,
#    (...)    191         **kwargs,
#     192     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyXLMS/parser/parser_xldbse_plink.py:542, in read_plink(files, spectrum_file_parser, scan_nr_parser, decoy_prefix, parse_modifications, modifications, sep, decimal, verbose)
#     540 ## process data
#     541 for input in inputs:
# --> 542     if detect_plink_filetype(input, sep=sep, decimal=decimal) == "crosslinks":
#     543         data = __read_plink_cross_linked_peptides_file(
#     544             input, sep=sep, decimal=decimal
#     545         )
#     546         for i, row in tqdm(
#     547             data.iterrows(), total=data.shape[0], desc="Reading pLink crosslinks..."
#     548         ):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyXLMS/parser/parser_xldbse_plink.py:411, in detect_plink_filetype(file, sep, decimal)
#     407         raise ValueError(
#     408             "The provided file seems not to be one of the support pLink input files!"
#     409         )
#     410 if lines[1].startswith(sep):
# --> 411     _ = __read_plink_cross_linked_peptides_file(file, sep=sep, decimal=decimal)
#     412     return "crosslinks"
#     413 df = pd.read_csv(file, sep=sep, decimal=decimal, low_memory=False)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyXLMS/parser/parser_xldbse_plink.py:277, in __read_plink_cross_linked_peptides_file(file, sep, decimal)
#     268 colnames = df.columns.values.tolist()
#     269 if not (
#     270     "Peptide_Order" in colnames
#     271     and "Peptide" in colnames
#    (...)    275     and "Protein_Type" in colnames
#     276 ):
# --> 277     raise ValueError(
#     278         "The provided file seems not to be a pLink cross-linked peptides file!"
#     279     )
#     280 return df
#
# ValueError: The provided file seems not to be a pLink cross-linked peptides file!

# %% [markdown]
# It's also possible to read multiple files into one `parser_result`, this for example makes sense if you have crosslinks and crosslink-spectrum-matches from the same run.

# %%
_ = transform.summary(parser_result)
# Out:
# Number of crosslinks: 252.0
# Number of unique crosslinks by peptide: 252.0
# Number of unique crosslinks by protein: 251.0
# Number of intra crosslinks: 249.0
# Number of inter crosslinks: 3.0
# Number of target-target crosslinks: 252.0
# Number of target-decoy crosslinks: 0.0
# Number of decoy-decoy crosslinks: 0.0
# Minimum crosslink score: nan
# Maximum crosslink score: nan

# %% [markdown]
# If the `parser_result` contains both crosslinks and CSMs, summary statistics for both will be calculated by `transform.summary()`.
#
# *****

# %%
parser_result = parser.read(
    "../../data/plink2/Cas9_plus10_2024.06.20.filtered_cross-linked_peptides.csv",
    engine="pLink",
    crosslinker="DSS",
    parse_modifications=False,
)
# Out:
# Reading pLink crosslinks...: 100%|██████████| 252/252 [00:00<00:00, 15299.70it/s]

# %% [markdown]
# We can also tell the parser to not parse modifications via `parse_modifications=False`, this might be useful if you don't care about post-translational-modifications, or if you have unknown modifications in your results that you would have to manually specify - _and you don't want to do that_.
#
# In case you want to parse modifications but have unknown modifications in your results, you have to set them via the `modifications` parameter that can be passed via `**kwargs` to `parser.read_plink()`. More about that later...

# %%
sample_csm = parser_result["crosslink-spectrum-matches"][0]
for k, v in sample_csm.items():
    print(f"{k}: {v}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sample_csm = parser_result["crosslink-spectrum-matches"][0]
#       2 for k, v in sample_csm.items():
#       3     print(f"{k}: {v}")
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# Notice that this time the fields `alpha_modifications` and `beta_modifications` are empty (`None`) for our sample CSM in contrast to when we looked at it further up.
#
# *****

# %% [markdown]
# ## **Reading pLink Result Files via `parser.read_pLink()`**

# %%
parser_result = parser.read_plink(
    "../../data/plink2/Cas9_plus10_2024.06.20.filtered_cross-linked_peptides.csv"
)
# Out:
# Reading pLink crosslinks...: 100%|██████████| 252/252 [00:00<00:00, 17982.32it/s]

# %% [markdown]
# We can also read any pLink result file using the `parser.read_plink()` method which allows a more nuanced control over reading pLink result files - even though theoretically everything can be done with the `parser.read()` function as well. You can read the documentation for the `parser.read_plink()` method here: [**docs**](https://hgb-bin-proteomics.github.io/pyXLMS/pyXLMS.parser.html#pyXLMS.parser.parser_xldbse_plink.read_plink).

# %%
_ = transform.summary(parser_result)
# Out:
# Number of crosslinks: 252.0
# Number of unique crosslinks by peptide: 252.0
# Number of unique crosslinks by protein: 251.0
# Number of intra crosslinks: 249.0
# Number of inter crosslinks: 3.0
# Number of target-target crosslinks: 252.0
# Number of target-decoy crosslinks: 0.0
# Number of decoy-decoy crosslinks: 0.0
# Minimum crosslink score: nan
# Maximum crosslink score: nan

# %% [markdown]
# *****

# %%
from pyXLMS.constants import MODIFICATIONS

MODIFICATIONS
# Out:
# {'Carbamidomethyl': 57.021464,
#  'Oxidation': 15.994915,
#  'Phospho': 79.966331,
#  'Acetyl': 42.010565,
#  'BS3': 138.06808,
#  'DSS': 138.06808,
#  'DSSO': 158.00376,
#  'DSBU': 196.08479231,
#  'ADH': 138.09054635,
#  'DSBSO': 308.03883,
#  'PhoX': 209.97181}

# %% [markdown]
# By default the pLink parser considers all modifications that are in `constants.MODIFICATIONS` as shown above for **pyXLMS version 1.4.3** - a full list of default modifications is given here: [**docs**](https://hgb-bin-proteomics.github.io/pyXLMS/pyXLMS.html#pyXLMS.constants.MODIFICATIONS).

# %%
my_mods = dict(MODIFICATIONS)
my_mods["Methyl"] = 14.01565
my_mods
# Out:
# {'Carbamidomethyl': 57.021464,
#  'Oxidation': 15.994915,
#  'Phospho': 79.966331,
#  'Acetyl': 42.010565,
#  'BS3': 138.06808,
#  'DSS': 138.06808,
#  'DSSO': 158.00376,
#  'DSBU': 196.08479231,
#  'ADH': 138.09054635,
#  'DSBSO': 308.03883,
#  'PhoX': 209.97181,
#  'Methyl': 14.01565}

# %% [markdown]
# If you have any additional modifications in your result file(s) the parser needs to know about them, which is done via the `modifications` parameter that allows for passing a custom dictionary of modifications. It is usually a good idea to base this custom dictionary on `constants.MODIFICATIONS` and add your modifications after, as shown above for methylation.

# %%
parser_result = parser.read_plink(
    "../../data/plink2/Cas9_plus10_2024.06.20.filtered_cross-linked_peptides.csv",
    modifications=my_mods,
)
# Out:
# Reading pLink crosslinks...: 100%|██████████| 252/252 [00:00<00:00, 17396.30it/s]

# %% [markdown]
# You can then pass the full list of expected modifications `my_mods` via the `modifications` parameter.

# %%
_ = transform.summary(parser_result)
# Out:
# Number of crosslinks: 252.0
# Number of unique crosslinks by peptide: 252.0
# Number of unique crosslinks by protein: 251.0
# Number of intra crosslinks: 249.0
# Number of inter crosslinks: 3.0
# Number of target-target crosslinks: 252.0
# Number of target-decoy crosslinks: 0.0
# Number of decoy-decoy crosslinks: 0.0
# Minimum crosslink score: nan
# Maximum crosslink score: nan

# %% [markdown]
# *****

# %% [markdown]
# There are several other parameters that can be set, you can read more about them here: [**docs**](https://hgb-bin-proteomics.github.io/pyXLMS/pyXLMS.parser.html#pyXLMS.parser.parser_xldbse_msannika.read_msannika).
